# %%
import json
import os
import connection

# %%
print('Downloading Historical Data for ')
# data = connection.getHistoricalData()
data = json.load(open('data_1.txt', 'r'))
if data == 'Error':
    print('Some Error in data Fetching')
# Out:
# Downloading Historical Data for

# %%
logFile = open('params_trial.log', 'w')
# print("Start Processing Data: ", len(data["response"]["Record"]))
state = ['Fan on Not Moving', 'idle', 'Fan off Moving', 'Fan on Moving']

p1 = "tcpConnections" + ',' + "dnsSize"
p2 = "totalTasks" + ',' + "runningTasks" + ',' + "sleepingTasks" + ',' + "stoppedTasks" + ',' + "zombie"
p3 = "totalMemory" + ',' + "freeMemory" + ',' + "usedMemory" + ',' + "bufferCache"
p4 = "totalSwap" + ',' + "freeSwap" + ',' + "usedSwap" + ',' + "availableMemory"
p5 = "deviceState"
p6_list=[]
SAR=json.loads(data['response']['Record'][-1]["Value"]["dynamicParams"].replace("'", "\""))['System Activity Report']
for item, vals in SAR.items():
    if type(vals)==dict:
        for key,val in vals.items():
            p6_list.append(item+'_'+key)
logFile.write(p1 + ',' + p2 + ',' + p3 + ',' + p4 + ',' + p5 + ',' + ','.join(p6_list) + '\n')
# Out:
# 1116

# %%
for index, val in enumerate(data["response"]["Record"]):
    try:
        dynamicParams = json.loads(str(val["Value"]["dynamicParams"]).replace("'", "\""))
        
        #TCP connections
        tcpConnections = str(len(dynamicParams["TCP"]["TCP"]))
        dnsSize = str(len(dynamicParams["DNS"]["DNS"]))
        p1 = tcpConnections + ',' + dnsSize
        
        #MetaData of Tasks 
        totalTasks = dynamicParams["Kernel Processes"]["MetaData"]["Tasks"]["total"]
        runningTasks = dynamicParams["Kernel Processes"]["MetaData"]["Tasks"]["running"]
        sleepingTasks = dynamicParams["Kernel Processes"]["MetaData"]["Tasks"]["sleeping"]
        stoppedTasks = dynamicParams["Kernel Processes"]["MetaData"]["Tasks"]["stopped"]
        zombie = dynamicParams["Kernel Processes"]["MetaData"]["Tasks"]["zombie"]
        p2 = totalTasks + ',' + runningTasks + ',' + sleepingTasks + ',' + stoppedTasks + ',' + zombie
        
        #Memory Utilisation
        totalMemory = dynamicParams["Kernel Processes"]["MetaData"]["MiB Mem "]["total"]
        freeMemory = dynamicParams["Kernel Processes"]["MetaData"]["MiB Mem "]["free"]
        usedMemory = dynamicParams["Kernel Processes"]["MetaData"]["MiB Mem "]["used"]
        bufferCache = dynamicParams["Kernel Processes"]["MetaData"]["MiB Mem "]["buff/cache"]
        p3 = totalMemory + ',' + freeMemory + ',' + usedMemory + ',' + bufferCache
        
        #Swap Utilisation
        totalSwap = dynamicParams["Kernel Processes"]["MetaData"]["MiB Swap"]["total"]
        freeSwap = dynamicParams["Kernel Processes"]["MetaData"]["MiB Swap"]["free"]
        usedSwap = dynamicParams["Kernel Processes"]["MetaData"]["MiB Swap"]["used"]
        availableMemory = dynamicParams["Kernel Processes"]["MetaData"]["MiB Swap"]["avail Mem"]
        p4 = totalSwap + ',' + freeSwap + ',' + usedSwap + ',' + availableMemory
        
        #Device State (for Data labelling)
        deviceState = dynamicParams["State"]
        p5 = str(state.index(deviceState))
        
        #System Activity Report
        p6_values=[]
        SAR=dynamicParams['System Activity Report']        
        if SAR:
            for key in p6_list:                
                if '_' in key:
                    header,item=key.split('_')                    
                    value=SAR[header][item]                    
                    p6_values.append(value)                    
        
        # print(p1 + ',' + p2 + ',' + p3 + ',' + p4 + ',' + p5 + '\n')
        logFile.write(p1 + ',' + p2 + ',' + p3 + ',' + p4 + ',' + p5 + ',' + ','.join(p6_values)+'\n')
        
    except Exception as e:
        print('Something Wrong with Record: ', index)
        # if index == 626:
        print(e)
            # print(e, str(val["Value"]["dynamicParams"]).replace("'", "\""))
            # print(str(val["Value"]["dynamicParams"]))
        continue

logFile.close()
# os.system('copy params_trial.log params_trial.csv')
# Out:
# Something Wrong with Record:  25
# Expecting value: line 1 column 18361 (char 18360)
# Something Wrong with Record:  32
# Expecting value: line 1 column 16903 (char 16902)
# Something Wrong with Record:  47
# Expecting value: line 1 column 17132 (char 17131)
# Something Wrong with Record:  48
# Expecting value: line 1 column 23945 (char 23944)
# Something Wrong with Record:  52
# Expecting value: line 1 column 15729 (char 15728)
# Something Wrong with Record:  81
# Expecting value: line 1 column 18974 (char 18973)
# Something Wrong with Record:  84
# Expecting value: line 1 column 24051 (char 24050)
# Something Wrong with Record:  85
# Expecting value: line 1 column 18145 (char 18144)
# Something Wrong with Record:  94
# Expecting value: line 1 column 27348 (char 27347)
# Something Wrong with Record:  112
# Expecting value: line 1 column 20970 (char 20969)
# Something Wrong with Record:  127
# Expecting value: line 1 column 18897 (char 18896)
# Something Wrong with Record:  144
# Expecting value: line 1 column 13856 (char 13855)
# Something Wrong with Record:  153
# Expecting value: line 1 column 24415 (char 24414)
# Something Wrong with Record:  155
# Expecting value: line 1 column 18145 (char 18144)
# Something Wrong with Record:  163
# Expecting value: line 1 column 17785 (char 17784)
# Something Wrong with Record:  172
# Expecting value: line 1 column 24074 (char 24073)
# Something Wrong with Record:  173
# Expecting value: line 1 column 13513 (char 13512)
# Something Wrong with Record:  174
# Expecting value: line 1 column 22965 (char 22964)
# Something Wrong with Record:  175
# Expecting value: line 1 column 16666 (char 16665)
# Something Wrong with Record:  187
# Expecting value: line 1 column 20415 (char 20414)
# Something Wrong with Record:  197
# Expecting value: line 1 column 18959 (char 18958)
# Something Wrong with Record:  205
# Expecting value: line 1 column 17553 (char 17552)
# Something Wrong with Record:  206
# Expecting value: line 1 column 17779 (char 17778)
# Something Wrong with Record:  208
# Expecting value: line 1 column 20359 (char 20358)
# Something Wrong with Record:  223
# Expecting value: line 1 column 19996 (char 19995)
# Something Wrong with Record:  234
# Expecting value: line 1 column 16071 (char 16070)
# Something Wrong with Record:  235
# Expecting value: line 1 column 13130 (char 13129)
# Something Wrong with Record:  251
# Expecting value: line 1 column 15774 (char 15773)
# Something Wrong with Record:  258
